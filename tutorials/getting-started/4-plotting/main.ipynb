# %%
import matplotlib.pyplot as plt

from data.data import air_quality

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# ## Quick visual check of the data

# %%
air_quality.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
plt.show()

# %% [markdown]
# ## Plot only the columns of the data table with data from Paris

# %%
air_quality["station_paris"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
plt.show()

# %% [markdown]
# ## Visually compare NO<sub>2</sub> values measured in London vs. Paris

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
plt.show()

# %% [markdown]
# ## List plot methods

# %%
[method_name for method_name in dir(air_quality.plot) if not method_name.startswith("_")]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ## Show box plot for air quality

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
plt.show()

# %% [markdown]
# ## Let each column have a separate subplot

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)
plt.show()

# %% [markdown]
# ## Customize, extend, or save the resulting plot

# %%
fig, axs = plt.subplots(figsize=(12, 4))
air_quality.plot.area(ax=axs)
# Out:
# <Axes: xlabel='datetime'>

# %%
axs.set_ylabel("NO$_2$ concentration")
# Out:
# Text(4.444444444444452, 0.5, 'NO$_2$ concentration')

# %%
fig.savefig("no2_concentrations.png")

# %%
plt.show()
