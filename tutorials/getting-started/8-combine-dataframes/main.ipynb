# %%
import pandas as pd

from data.data import air_quality_no2_long as air_quality_no2, air_quality_pm25, stations_coord, air_quality_parameters

# %%
air_quality_no2.head()
# Out:
#     city country                   date.utc location parameter  value   unit
# 0  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0  µg/m³
# 1  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8  µg/m³
# 2  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5  µg/m³
# 3  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9  µg/m³
# 4  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4  µg/m³

# %%
air_quality_pm25.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %% [markdown]
# # Combine data from multiple tables
#
# ## Concatenating objects

# %%
air_quality = pd.concat([air_quality_pm25, air_quality_no2], axis=0)
air_quality.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
air_quality_pm25.shape
# Out:
# (1110, 7)

# %%
air_quality_no2.shape
# Out:
# (2068, 7)

# %%
air_quality.shape
# Out:
# (3178, 7)

# %%
qir_quality = air_quality.sort_values("date.utc")
air_quality.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
air_quality_ = pd.concat([air_quality_pm25, air_quality_no2], keys=["PM25", "NO2"])
air_quality_.head()
# Out:
#              city country                   date.utc location parameter  \
# PM25 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25
#      1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25
#      2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25
#      3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25
#      4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25
#
#         value   unit
# PM25 0   18.0  µg/m³
#      1    6.5  µg/m³
#      2   18.5  µg/m³
#      3   16.0  µg/m³
#      4    7.5  µg/m³

# %% [markdown]
# # Join tables using a common identifier

# %%
stations_coord.head()
# Out:
#   location  coordinates.latitude  coordinates.longitude
# 0  BELAL01              51.23619                4.38522
# 1  BELHB23              51.17030                4.34100
# 2  BELLD01              51.10998                5.00486
# 3  BELLD02              51.12038                5.02155
# 4  BELR833              51.32766                4.36226

# %%
qir_quality.head()
# Out:
#            city country                   date.utc            location  \
# 2067     London      GB  2019-05-07 01:00:00+00:00  London Westminster
# 1003      Paris      FR  2019-05-07 01:00:00+00:00             FR04014
# 100   Antwerpen      BE  2019-05-07 01:00:00+00:00             BETR801
# 1098  Antwerpen      BE  2019-05-07 01:00:00+00:00             BETR801
# 1109     London      GB  2019-05-07 01:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 2067       no2   23.0  µg/m³
# 1003       no2   25.0  µg/m³
# 100       pm25   12.5  µg/m³
# 1098       no2   50.5  µg/m³
# 1109      pm25    8.0  µg/m³

# %%
air_quality = pd.merge(air_quality, stations_coord, how="left", on="location")
air_quality.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit  coordinates.latitude  coordinates.longitude
# 0  µg/m³              51.20966                4.43182
# 1  µg/m³              51.20966                4.43182
# 2  µg/m³              51.20966                4.43182
# 3  µg/m³              51.20966                4.43182
# 4  µg/m³              51.20966                4.43182

# %%
air_quality = pd.merge(air_quality, air_quality_parameters, how="left", left_on="parameter", right_on="id")
air_quality.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit  coordinates.latitude  coordinates.longitude    id  \
# 0  µg/m³              51.20966                4.43182  pm25
# 1  µg/m³              51.20966                4.43182  pm25
# 2  µg/m³              51.20966                4.43182  pm25
# 3  µg/m³              51.20966                4.43182  pm25
# 4  µg/m³              51.20966                4.43182  pm25
#
#                                          description   name
# 0  Particulate matter less than 2.5 micrometers i...  PM2.5
# ...
